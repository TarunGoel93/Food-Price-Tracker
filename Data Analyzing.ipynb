# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv(r"C:\Users\Dell\Downloads\Intership\Projects\Food Price Tracker\WLD_RTFP_country_2023-10-02.csv",encoding='latin1')
print(df)
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  01-01-2007
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  01-02-2007
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  01-03-2007
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  01-04-2007
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  01-05-2007
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 4793  2.74  2.78  2.70   2.75      -0.28  Yemen, Rep.  YEM  01-06-2023
# 4794  2.79  2.83  2.75   2.81      -1.85  Yemen, Rep.  YEM  01-07-2023
# 4795  2.85  2.89  2.81   2.83      -3.17  Yemen, Rep.  YEM  01-08-2023
# 4796  2.86  2.97  2.82   2.97       1.68  Yemen, Rep.  YEM  01-09-2023
# 4797  3.06  3.11  2.98   2.98       3.76  Yemen, Rep.  YEM  01-10-2023
#
# [4798 rows x 8 columns]

# %%
df['Close'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='PuRd')
# Out:
# <Axes: >

# %%
df.drop(["Inflation","country","ISO3","date"],axis=1,inplace=True)
df.head(5)
# Out:
#    Open  High   Low  Close
# 0  0.53  0.54  0.53   0.53
# 1  0.53  0.54  0.53   0.53
# 2  0.54  0.54  0.53   0.53
# 3  0.53  0.55  0.53   0.55
# 4  0.56  0.57  0.56   0.57

# %%
X=df.drop("Close",axis=1)
y=df["Close"]

# %%
X
# Out:
#       Open  High   Low
# 0     0.53  0.54  0.53
# 1     0.53  0.54  0.53
# 2     0.54  0.54  0.53
# 3     0.53  0.55  0.53
# 4     0.56  0.57  0.56
# ...    ...   ...   ...
# 4793  2.74  2.78  2.70
# 4794  2.79  2.83  2.75
# 4795  2.85  2.89  2.81
# 4796  2.86  2.97  2.82
# 4797  3.06  3.11  2.98
#
# [4798 rows x 3 columns]

# %%
y
# Out:
# 0       0.53
# 1       0.53
# 2       0.53
# 3       0.55
# 4       0.57
#         ...
# 4793    2.75
# 4794    2.81
# 4795    2.83
# 4796    2.97
# 4797    2.98
# Name: Close, Length: 4798, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
y = pd.cut(y, bins=3, labels=False)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=5)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_train= sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from  sklearn.linear_model import LogisticRegression
